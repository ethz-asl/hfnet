# %% [markdown]
# ### Local descriptors distillation (SuperPoint)

# %%
# !python hfnet/export_predictions.py hfnet/configs/superpoint_export_distill.yaml superpoint_predictions --keys local_descriptor_map,dense_scores --as_dataset
# Out:
# [08/05/2022 08:54:29 INFO] Starting export with configuration:
# {'data': {'image_dirs': ['self_driving/images/images1',
#                          'self_driving/images/images2'],
#           'name': 'distillation',
#           'preprocessing': {'grayscale': True, 'resize': [480, 640]},
#           'shuffle': False},
#  'model': {'detector_threshold': 0.005,
#            'image_channels': 1,
#            'name': 'super_point_pytorch',
#            'nms_radius': 0},
#  'weights': 'superpoint_v1.pth'}
# /home/server/anaconda3/envs/hfnet/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# ...

# %%
# !python hfnet/export_predictions.py hfnet/configs/netvlad_export_distill.yaml global_decriptors --keys global_descriptor --as_dataset
# Out:
# [08/05/2022 13:27:23 INFO] Starting export with configuration:
# {'data': {'image_dirs': ['self_driving/images/images1',
#                          'self_driving/images/images2'],
#           'name': 'distillation',
#           'preprocessing': {'grayscale': False, 'resize': [480, 640]},
#           'shuffle': False},
#  'model': {'image_channels': 3, 'name': 'netvlad_original'},
#  'weights': 'vd16_pitts30k_conv5_3_vlad_preL2_intra_white/vd16_pitts30k_conv5_3_vlad_preL2_intra_white'}
# /home/server/anaconda3/envs/hfnet/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# ...

# %% [markdown]
# ### Train Hfnet with MobileNetV2 weights

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
# !python hfnet/train.py hfnet/configs/hfnet_train_distill.yaml hfnet
# Out:
# /home/server/anaconda3/envs/hfnet/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/server/anaconda3/envs/hfnet/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/server/anaconda3/envs/hfnet/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# ### Deployment of Hfnet trained model

# %%
# !python hfnet/export_model.py hfnet/configs/hfnet_train_distill.yaml hfnet
# Out:
# /home/server/anaconda3/envs/hfnet/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/server/anaconda3/envs/hfnet/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/server/anaconda3/envs/hfnet/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !python hfnet/pb_viewer.py
# Out:
# /home/server/anaconda3/envs/hfnet/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/server/anaconda3/envs/hfnet/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/server/anaconda3/envs/hfnet/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
import tensorflow as tf

g = tf.Graph()

with g.as_default() as g:
    tf.train.import_meta_graph('/home/server/hfnet/log/hfnet/model.ckpt-1800.data-00000-of-00001')

with tf.Session(graph=g) as sess:
    file_writer = tf.summary.FileWriter(logdir='checkpoint_log_dir/faceboxes', graph=g)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-6-bf574d95b7a5> in <module>
#       4
#       5 with g.as_default() as g:
# ----> 6     tf.train.import_meta_graph('/home/server/hfnet/log/hfnet/model.ckpt-1800.data-00000-of-00001')
#       7
#       8 with tf.Session(graph=g) as sess:
#
# ~/anaconda3/envs/hfnet/lib/python3.6/site-packages/tensorflow/python/training/saver.py in import_meta_graph(meta_graph_or_file, clear_devices, import_scope, **kwargs)
#    1672   """  # pylint: disable=g-doc-exception
#    1673   return _import_meta_graph_with_return_elements(
# -> 1674       meta_graph_or_file, clear_devices, import_scope, **kwargs)[0]
#    1675
#    1676
#
# ~/anaconda3/envs/hfnet/lib/python3.6/site-packages/tensorflow/python/training/saver.py in _import_meta_graph_with_return_elements(meta_graph_or_file, clear_devices, import_scope, return_elements, **kwargs)
# ...
